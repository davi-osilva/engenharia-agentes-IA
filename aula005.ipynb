# %% [markdown]
# <a href="https://colab.research.google.com/github/davi-osilva/engenharia-agentes-IA/blob/main/aula005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Conhecendo o Pandas

# %%
import pandas as pd
import numpy as np

# Definindo os dados para as colunas
nomes_produtos = [f"Produto {i+1}" for i in range(50)]
categorias_produtos = np.random.choice(["Eletrônicos", "Livros", "Roupas", "Alimentos", "Brinquedos"], 50)
precos_produtos = np.random.uniform(10.0, 500.0, 50).round(2)
itens_vendidos = np.random.randint(1, 1000, 50)
avaliacoes_produtos = np.random.uniform(1.0, 5.0, 50).round(1)

# Criando o DataFrame
df_produtos = pd.DataFrame({
    "Nome do produto": nomes_produtos,
    "Categoria do produto": categorias_produtos,
    "Preço do produto": precos_produtos,
    "Itens vendidos": itens_vendidos,
    "Avaliação do produto": avaliacoes_produtos
})

# %%
df_produtos.head()
# Out:
#   Nome do produto Categoria do produto  Preço do produto  Itens vendidos  \
# 0       Produto 1            Alimentos            387.27             544
# 1       Produto 2           Brinquedos            421.05             208
# 2       Produto 3           Brinquedos            171.81             168
# 3       Produto 4           Brinquedos            229.73             613
# 4       Produto 5            Alimentos            170.04             523
#
#    Avaliação do produto
# 0                   4.6
# 1                   4.5
# 2                   4.1
# 3                   1.7
# 4                   1.8

# %%
df_produtos['Categoria do produto']
# Out:
# 0       Alimentos
# 1      Brinquedos
# 2      Brinquedos
# 3      Brinquedos
# 4       Alimentos
# 5          Roupas
# 6          Roupas
# 7          Livros
# 8       Alimentos
# 9     Eletrônicos
# 10         Livros
# 11         Roupas
# 12      Alimentos
# 13      Alimentos
# 14    Eletrônicos
# 15     Brinquedos
# 16         Livros
# 17     Brinquedos
# 18         Roupas
# 19      Alimentos
# 20    Eletrônicos
# 21     Brinquedos
# 22         Roupas
# 23         Roupas
# 24         Roupas
# 25     Brinquedos
# 26    Eletrônicos
# 27      Alimentos
# 28      Alimentos
# 29         Roupas
# 30    Eletrônicos
# 31         Roupas
# 32     Brinquedos
# 33         Roupas
# 34         Roupas
# 35    Eletrônicos
# 36      Alimentos
# 37      Alimentos
# 38         Livros
# 39         Livros
# 40     Brinquedos
# 41         Roupas
# 42         Roupas
# 43     Brinquedos
# 44     Brinquedos
# 45    Eletrônicos
# 46         Livros
# 47      Alimentos
# 48         Roupas
# 49     Brinquedos
# Name: Categoria do produto, dtype: object

# %%
df_produtos['Categoria do produto'].unique()
# Out:
# array(['Alimentos', 'Brinquedos', 'Roupas', 'Livros', 'Eletrônicos'],
#       dtype=object)

# %%
set(df_produtos['Categoria do produto'])
# Out:
# {'Alimentos', 'Brinquedos', 'Eletrônicos', 'Livros', 'Roupas'}

# %% [markdown]
# Filtrando elementos de um DataFrame

# %%
df_produtos[df_produtos['Categoria do produto'] == 'Eletrônicos']
# Out:
#    Nome do produto Categoria do produto  Preço do produto  Itens vendidos  \
# 9       Produto 10          Eletrônicos            418.61             829
# 14      Produto 15          Eletrônicos            174.22             411
# 20      Produto 21          Eletrônicos            411.74             846
# 26      Produto 27          Eletrônicos            366.08             319
# 30      Produto 31          Eletrônicos            492.04             953
# 35      Produto 36          Eletrônicos            130.57              94
# 45      Produto 46          Eletrônicos             28.98             580
#
#     Avaliação do produto
# 9                    1.3
# 14                   3.7
# 20                   1.0
# 26                   4.5
# 30                   4.5
# 35                   4.2
# 45                   2.1

# %%
df_produtos[df_produtos['Avaliação do produto'] < 2]
# Out:
#    Nome do produto Categoria do produto  Preço do produto  Itens vendidos  \
#
# 18                   1.9
# 19                   4.1
# 20                   1.0
# 21                   3.3
# 22                   1.4
# 23                   1.4
# 24                   4.6
# 25                   3.9
# 26                   4.5
# 27                   3.2
# 28                   4.8
# 29                   4.7
# 30                   4.5
# 31                   4.8
# 32                   2.2
# 33                   3.9
# 34                   2.8
# 35                   4.2
# 36                   2.8
# 37                   4.8
# 38                   2.6
# 39                   3.1
# 40                   1.2
# 41                   4.7
# 42                   2.6
# 43                   3.4
# 44                   1.9

# %%
df_produtos_indice = df_produtos.set_index('Nome do produto')

# %%
df_produtos_indice.loc["Produto 45", "Categoria do produto"]
# Out:
# 'Brinquedos'

# %%
df_produtos_indice.loc[["Produto 45", "Produto 44", "Produto 43"], ["Categoria do produto", "Preço do produto"]]
# Out:
#                 Categoria do produto  Preço do produto
# Nome do produto
# Produto 45                Brinquedos            430.45
# Produto 44                Brinquedos            102.36
# Produto 43                    Roupas            435.29

# %% [markdown]
# Desafio de reviews com Pandas

# %%
# !pip install groq --quiet
from groq import Groq
import os

# %%
os.environ["GROQ_API_KEY"] = userdata.get("Groq_API_key")
client = Groq()

# %%
df = pd.read_csv('reviews.csv')

# %%
df.head()
# Out:
#        reviewerID        asin  reviewerName  \
# 0  A2FII3I2MBMUIA  B007WTAJTO           1K3
# 1   A3H99DFEG68SR  B007WTAJTO           1m2
# 2  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men
# 3  A2IDCSC6NVONIZ  B007WTAJTO       2Cents!
# 4  A26YHXZD5UFPVQ  B007WTAJTO    2K1Toaster
#
#                                           reviewText  unixReviewTime  \
# 0  it works as expected. I should have sprung for...      1356220800
# 1  This think has worked out great.Had a diff. br...      1384992000
# 2  Bought it with Retail Packaging, arrived legit...      1373673600
# 3  It's mini storage.  It doesn't do anything els...      1367193600
# 4  I have it in my phone and it never skips a bea...      1382140800
#
#    reviewTime  day_diff  helpful_yes  total_vote
# 0  23/12/2012       715            0           0
# 1  21/11/2013       382            0           0
# 2  13/07/2013       513            0           0
# 3  29/04/2013       588            0           0
# 4  19/10/2013       415            0           0

# %%
reviews = df['reviewText']
feedback = []

# %%
feedback = []

for review in reviews:
    completion = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {
                "role": "user",
                "content": f"Classifique essa review como positiva, negativa ou neutra. Só digite uma das 3 e mais nada: {review}"
            }
        ],
        temperature=0,
        max_completion_tokens=10
    )

    resposta = completion.choices[0].message.content
    feedback.append(resposta)

# %%
df['Feedback'] = feedback

# %%
df.head()
# Out:
#        reviewerID        asin  reviewerName  \
# 0  A2FII3I2MBMUIA  B007WTAJTO           1K3
# 1   A3H99DFEG68SR  B007WTAJTO           1m2
# 2  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men
# 3  A2IDCSC6NVONIZ  B007WTAJTO       2Cents!
# 4  A26YHXZD5UFPVQ  B007WTAJTO    2K1Toaster
#
#                                           reviewText  unixReviewTime  \
# 0  it works as expected. I should have sprung for...      1356220800
# 1  This think has worked out great.Had a diff. br...      1384992000
# 2  Bought it with Retail Packaging, arrived legit...      1373673600
# 3  It's mini storage.  It doesn't do anything els...      1367193600
# 4  I have it in my phone and it never skips a bea...      1382140800
#
#    reviewTime  day_diff  helpful_yes  total_vote  Feedback
# 0  23/12/2012       715            0           0    Neutra
# 1  21/11/2013       382            0           0  Positiva
# 2  13/07/2013       513            0           0  Positiva
# 3  29/04/2013       588            0           0  Positiva
# 4  19/10/2013       415            0           0  Positiva
